# %%
# !git clone https://github.com/arcee-ai/mergekit.git
# %cd mergekit
# !pip install -e .  # install the package and make scripts available
# %cd ..
# Out:
# Cloning into 'mergekit'...
# remote: Enumerating objects: 2420, done.
# remote: Counting objects: 100% (855/855), done.
# remote: Compressing objects: 100% (199/199), done.
# remote: Total 2420 (delta 769), reused 656 (delta 656), pack-reused 1565 (from 2)
# Receiving objects: 100% (2420/2420), 735.21 KiB | 2.26 MiB/s, done.
# Resolving deltas: 100% (1675/1675), done.
# /content/mergekit
# Obtaining file:///content/mergekit
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.4/149.4 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.7/99.7 kB 9.9 MB/s eta 0:00:00
# ...

# %%
import os
if not os.path.exists('storage'):
  os.makedirs('storage')

st = '''
models:
  - model: augmxnt/shisa-gamma-7b-v1
    parameters:
      weight: 0.5
      density: 0.6
  - model: WizardLMTeam/WizardMath-7B-V1.1
    parameters:
      weight: 0.5
      density: 0.6
  - model: GAIR/Abel-7B-002
    parameters:
      weight: 0.5
      density: 0.6
merge_method: dare_ties
base_model: mistralai/Mistral-7B-v0.1
parameters:
normalize: true
dtype: bfloat16
'''

with open('./config.yml', 'w') as file:
  file.write(st)

# %%
# !pip install huggingface_hub

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
# !mergekit-yaml ./config.yml ./storage
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#
# pytorch_model-00001-of-00002.bin:  92% 9.10G/9.94G [03:44<00:19, 42.3MB/s]
#
#
# pytorch_model-00001-of-00002.bin:  92% 9.11G/9.94G [03:44<00:19, 42.3MB/s]
#
#
# pytorch_model-00001-of-00002.bin:  92% 9.12G/9.94G [03:44<00:16, 48.3MB/s]
#
#
# pytorch_model-00001-of-00002.bin:  92% 9.13G/9.94G [03:45<00:16, 48.4MB/s]
#
#
# pytorch_model-00001-of-00002.bin:  92% 9.14G/9.94G [03:45<00:17, 46.5MB/s]
#
#
# pytorch_model-00001-of-00002.bin:  92% 9.15G/9.94G [03:45<00:17, 45.2MB/s]
#
#
# pytorch_model-00001-of-00002.bin:  92% 9.16G/9.94G [03:45<00:17, 44.5MB/s]
#
#
# pytorch_model-00001-of-00002.bin:  92% 9.18G/9.94G [03:46<00:17, 44.0MB/s]
#
#
# pytorch_model-00001-of-00002.bin:  92% 9.19G/9.94G [03:46<00:17, 43.5MB/s]
#
#
# pytorch_model-00001-of-00002.bin:  92% 9.20G/9.94G [03:46<00:17, 43.0MB/s]
#
#
# pytorch_model-00001-of-00002.bin:  93% 9.21G/9.94G [03:46<00:17, 42.7MB/s]
#
#
# ...

# %%
# !huggingface-cli upload tunapan2113/merge-test-model ./storage .
# Out:
# Consider using `hf_transfer` for faster uploads. This solution comes with some limitations. See https://huggingface.co/docs/huggingface_hub/hf_transfer for more details.
# Start hashing 0 files.
# Finished hashing 0 files.
# No files have been modified since last commit. Skipping to prevent empty commit.
# https://huggingface.co/tunapan2113/merge-test-model/tree/main/.

# %%
# ダウンロードしたいフォルダを zip 圧縮する
# !zip -r /content/download.zip /content/storage/

# 圧縮した zip ファイルをダウンロードする
from google.colab import files
files.download("/content/download.zip")
# Out:
#   adding: content/storage/ (stored 0%)
